# %%
# Importando pacote para leitura do arquivo do excel
from pandas import read_excel
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="../files/ATP.jpg">

# %% [markdown]
# <h1 align="center">Análise Estatística - ATP - Big Data e Inteligência Analítica

# %% [markdown]
# <h2 align="center">Antonio de Padua Rodrigues Santos

# %% [markdown]
# <h2 align="center"> Estatística Descritiva

# %% [markdown]
# <h3> 1.1 Tema

# %% [markdown]
# <p><font size="3">Aspectos sociais que são determinantes na busca por satisfação no trabalho</font></p>

# %% [markdown]
# <h3> 1.2 Problema Pesquisado

# %% [markdown]
# <p>
#     <font size="3">A desigualdade trabalhista pode ser expressa exclusivamente pela raça ou idade?
#     <br>A educação poderia mudar o cenário em questão?
#     </font>
# </p>

# %% [markdown]
# <h3> 1.3 População e Amostra

# %% [markdown]
# <p>
#     <font size="3"/>A seguir iremos analisar nossa população e coletaremos algumas amostras para análise descritiva.
# </p>

# %%
# Carregando arquivo com os dados do projeto
populacao_original = read_excel("../files/Arquivo8.xlsx")

# %%
# Verificando o tamanho da 'população'
populacao_original
# Out:
#          Sexo  Idade Cor ou Raça  Total de moradores (grupo familiar)  \
# 0       Homem     20       Parda                                    4
# 1       Homem     20      Branca                                    4
# 2       Homem     20       Parda                                    4
# 3       Homem     20       Parda                                    5
# 4       Homem     20       Parda                                    7
# ...       ...    ...         ...                                  ...
# 51863  Mulher     49      Branca                                    1
# 51864   Homem     52      Branca                                    3
# 51865   Homem     52       Parda                                    5
# 51866   Homem     53      Branca                                    4
# 51867   Homem     54      Branca                                    1
#
#       Sabe ler e escrever? Qual o curso que frequenta? Frequentou escola?  \
# ...

# %% [markdown]
# <p> <br>
#     <font size="3"/> Nossa população é composta por 51868 registros, a seguir obteremos uma amostra de acordo com a técnica de amostragem simples.
# </p>

# %% [markdown]
# <img src="../files/amostragem.png">

# %%
# Definindo a amostragem conforme o resultado do cálculo
amostraN = populacao_original.sample(39693)

# %%
# Amostragem Simples Obtida
amostraN
# Out:
#          Sexo  Idade Cor ou Raça  Total de moradores (grupo familiar)  \
# 36999   Homem     41       Parda                                    3
# 10118  Mulher     61      Branca                                    2
# 13005  Mulher     66      Branca                                    2
# 18852  Mulher     72     Amarela                                    3
# 43755   Homem     51       Parda                                    7
# ...       ...    ...         ...                                  ...
# 41606   Homem     48       Parda                                    4
# 5085   Mulher     47      Branca                                    4
# 16081   Homem     73       Parda                                    2
# 42026  Mulher     48      Branca                                    4
# 42280   Homem     49      Branca                                    3
#
#       Sabe ler e escrever? Qual o curso que frequenta? Frequentou escola?  \
# ...

# %% [markdown]
# <p>
#     <font size="3"> O número obtido através do cálculo amostral, aproximadamente foi 39693 registros, a partir de agora realizaremos um processo exploratório dos dados para responder algumas perguntas.
# </p>

# %% [markdown]
# <h3 align="center">Quantidade de pessoas por sexo

# %% [markdown]
# <img src="../files/excel-sexo.jpg">

# %% [markdown]
# <p>
#     <font size="3"> A distribuição por sexo está equilibrada, além disso é importante ressaltar que os dados que estão sendo disponibilizados correspondem à amostra solicitada.
# </p>

# %% [markdown]
# <h3 align="center">Quantidade de pessoas por sexo e cor - Variáveis Agrupadoras

# %% [markdown]
# <img src="../files/excel-sexo-cor.jpg">

# %% [markdown]
# <img src="../files/excel-sexo-idade.jpg">
